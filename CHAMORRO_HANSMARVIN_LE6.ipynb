# %%
import random
import string

WORDLIST_FILENAME = "words.txt"


def load_words():
    print("Loading word list from file...")
    inFile = open(WORDLIST_FILENAME, 'r')
    line = inFile.readline()
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def choose_word(wordlist):
    return random.choice(wordlist)
wordlist = load_words()

def is_word_guessed(secret_word, letters_guessed):
    if secret_word=='':
        return True
    
    for c in secret_word:
        if c in letters_guessed:
            return is_word_guessed(secret_word[1:], letters_guessed)
        elif c not in letters_guessed:
            return False



def get_guessed_word(secret_word, letters_guessed):
    '''
    secret_word: string, the word the user is guessing
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string, comprised of letters, underscores (_), and spaces that represents
      which letters in secret_word have been guessed so far.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    result=''
    for e in secret_word:
        if e in letters_guessed:
            result+=e
        else:
            result+=' _ '
    return result



def get_available_letters(letters_guessed):
    '''
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string (of letters), comprised of letters that represents which letters have not
      yet been guessed.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    s=list(string.ascii_lowercase)
    for a in letters_guessed:
         if a in s:
            s.remove(a)
    return ''.join(str(x) for x in s)
    
    

def hangman(secret_word):

    print('Good day! I welcome you to the game, Hangman!')
    print('The word that I am thinking of has', len(secret_word), "letters long.")
    mistakesMade = 0
    lettersGuessed = []

    while 8 - mistakesMade > 0:
        if is_word_guessed(secret_word, lettersGuessed) == True:
            print('____________')
            print('Congratulations, you have found the word!')
            break
        else:
            print('____________')
            print('You have', 8 - mistakesMade, 'available guesses left.')
            print('Available letters:', get_available_letters(lettersGuessed))
            guess = str(input('Please guess a letter:')).lower()
            if guess in secret_word and guess not in lettersGuessed:
                lettersGuessed.append(guess)
                print('Good guess:', get_guessed_word(secret_word, lettersGuessed))
            elif guess in lettersGuessed:
                print("That letter is already guessed:", get_guessed_word(secret_word, lettersGuessed))
            elif guess not in secret_word:
                print("That letter is not in the word:", get_guessed_word(secret_word, lettersGuessed))
                lettersGuessed.append(guess)
                mistakesMade += 1
        if 8 - mistakesMade == 0:
            print('____________')
            print('Chances out! The word was', secret_word)
            break
        else:
            continue



if __name__ == "__main__":
    
    secret_word = choose_word(wordlist)
    hangman(secret_word)
# Out:
# Loading word list from file...
#    55900 words loaded.
# Good day! I welcome you to the game, Hangman!
# The word that I am thinking of has 8 letters long.
# ____________
# You have 8 available guesses left.
# Available letters: abcdefghijklmnopqrstuvwxyz
# Please guess a letter:q
# That letter is not in the word:  _  _  _  _  _  _  _  _
# ____________
# You have 7 available guesses left.
# Available letters: abcdefghijklmnoprstuvwxyz
# Please guess a letter:w
# That letter is not in the word:  _  _  _  _  _  _  _  _
# ____________
# You have 6 available guesses left.
# Available letters: abcdefghijklmnoprstuvxyz
# Please guess a letter:e
# Good guess:  _  _  _  _  _ e _  _
# ____________
# You have 6 available guesses left.
# Available letters: abcdfghijklmnoprstuvxyz
# Please guess a letter:r
# That letter is not in the word:  _  _  _  _  _ e _  _
# ____________
# You have 5 available guesses left.
# Available letters: abcdfghijklmnopstuvxyz
# Please guess a letter:t
# ...
